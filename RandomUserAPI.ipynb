# %%
pip install randomuser
# Out:
# Collecting randomuser
#   Downloading randomuser-1.6.tar.gz (5.0 kB)
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: randomuser
#   Building wheel for randomuser (setup.py) ... done
#   Created wheel for randomuser: filename=randomuser-1.6-py3-none-any.whl size=5068 sha256=ad14949bab5a9f47baea40548c5906c6e287c180393f207dc846ad898de5eb54
#   Stored in directory: /root/.cache/pip/wheels/fc/8d/74/bcdd5e8a9433bfa4c4f9c1cccbfec40139322a28d77f61e45e
# Successfully built randomuser
# Installing collected packages: randomuser
# Successfully installed randomuser-1.6

# %%
pip install pandas
# Out:
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (2.2.2)
# Requirement already satisfied: numpy>=1.23.2 in /usr/local/lib/python3.11/dist-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas) (2025.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)

# %%
from randomuser import RandomUser

# %%
r = RandomUser()

# %%
some_list = r.generate_users(10)
some_list
# Out:
# [<randomuser.RandomUser at 0x7b46c43e0510>,
#  <randomuser.RandomUser at 0x7b46c43e2050>,
#  <randomuser.RandomUser at 0x7b46c43e0f10>,
#  <randomuser.RandomUser at 0x7b46c43e2cd0>,
#  <randomuser.RandomUser at 0x7b46c43e1ed0>,
#  <randomuser.RandomUser at 0x7b46c43e2990>,
#  <randomuser.RandomUser at 0x7b46c43e2550>,
#  <randomuser.RandomUser at 0x7b46c43e1ad0>,
#  <randomuser.RandomUser at 0x7b46c43e1390>,
#  <randomuser.RandomUser at 0x7b46c43e0c90>]

# %%
name = r.get_full_name()

# %%
name
# Out:
# 'Violet Roberts'

# %%
for user in some_list:
  print(user.get_full_name(), ' ', user.get_email())
# Out:
# Johan Kristensen   johan.kristensen@example.com
# Lucas Mercier   lucas.mercier@example.com
# Marilou Clark   marilou.clark@example.com
# Jackson Carroll   jackson.carroll@example.com
# Ryder Fortin   ryder.fortin@example.com
# Molly Walker   molly.walker@example.com
# Walter Arnold   walter.arnold@example.com
# Miro Kyllo   miro.kyllo@example.com
# Tian Davidsen   tian.davidsen@example.com
# Marie Mortensen   marie.mortensen@example.com

# %%
for user in some_list:
  print(user.get_picture())
# Out:
# https://randomuser.me/api/portraits/men/97.jpg
# https://randomuser.me/api/portraits/men/99.jpg
# https://randomuser.me/api/portraits/women/51.jpg
# https://randomuser.me/api/portraits/men/41.jpg
# https://randomuser.me/api/portraits/men/55.jpg
# https://randomuser.me/api/portraits/women/86.jpg
# https://randomuser.me/api/portraits/men/24.jpg
# https://randomuser.me/api/portraits/men/38.jpg
# https://randomuser.me/api/portraits/men/50.jpg
# https://randomuser.me/api/portraits/women/64.jpg

# %%
import pandas as pd

# %%
def get_user():
  users = []
  for user in RandomUser.generate_users(10):
    users.append({"Name":user.get_full_name(),"Gender":user.get_gender(),"City":user.get_city(),"State":user.get_state(),"Email":user.get_email(), "DOB":user.get_dob(),"Picture":user.get_picture()})
  return pd.DataFrame(users)

# %%
get_user()
# Out:
#                Name  Gender           City        State  \
# 0     Fatmir Garcia    male      Unterkulm   Graubünden
# 1         Luke Ford    male     Evansville    Minnesota
# 2  Nicklas Pedersen    male   Øster Assels      Danmark
# 3      Jeppe Jensen    male       Nørrebro     Sjælland
# 4       Léa Lefevre  female  Saint-Étienne          Var
# 5         Mike Pena    male        Salford        Clwyd
# 6       Jack French    male    New Glasgow      Alberta
# 7      Roman Walker    male      Masterton  Marlborough
# 8    Elizabeth Wood  female       Tauranga   Wellington
# 9    Gomes Nogueira    male  Nova Friburgo      Sergipe
#
#                           Email                       DOB  \
# 0     fatmir.garcia@example.com  1945-06-08T13:18:50.437Z
# 1         luke.ford@example.com  1966-05-27T19:42:47.890Z
# 2  nicklas.pedersen@example.com  1953-01-04T00:38:00.480Z
# 3      jeppe.jensen@example.com  1994-12-10T21:19:55.428Z
# 4       lea.lefevre@example.com  1991-09-19T02:21:40.573Z
# 5         mike.pena@example.com  1964-03-30T22:24:19.393Z
# 6       jack.french@example.com  1957-07-25T13:11:40.021Z
# 7      roman.walker@example.com  1980-12-21T04:08:07.262Z
# 8    elizabeth.wood@example.com  1965-08-24T02:55:24.436Z
# 9    gomes.nogueira@example.com  1987-01-06T10:15:05.095Z
#
#                                             Picture
# 0     https://randomuser.me/api/portraits/men/1.jpg
# 1    https://randomuser.me/api/portraits/men/96.jpg
# 2    https://randomuser.me/api/portraits/men/17.jpg
# 3    https://randomuser.me/api/portraits/men/93.jpg
# 4  https://randomuser.me/api/portraits/women/80.jpg
# 5    https://randomuser.me/api/portraits/men/44.jpg
# 6    https://randomuser.me/api/portraits/men/47.jpg
# 7    https://randomuser.me/api/portraits/men/85.jpg
# 8   https://randomuser.me/api/portraits/women/0.jpg
# 9    https://randomuser.me/api/portraits/men/62.jpg

# %%
df1 = pd.DataFrame(get_user())
df1
# Out:
#                    Name  Gender                 City         State  \
# 0         Justin Picard    male  Champigny-sur-Marne  Haute-Vienne
# 1           Faith Lopez  female               Tralee         Kerry
# 2        Harper Ginnish  female            Deer Lake         Yukon
# 3         Carl Andersen    male            Silkeboeg   Midtjylland
# 4       Teus Vijfvinkel    male         Afferden Gld    Gelderland
# 5            Jack Sirko    male             Kingston       Nunavut
# 6          Darryl Bates    male               Durham    Merseyside
# 7            آراد قاسمی    male               زاهدان        گلستان
# 8          Manuel Kelly    male              Gilbert          Ohio
# 9  Lucas Or Luke Flores    male            Leicester        Durham
#
#                             Email                       DOB  \
# 0       justin.picard@example.com  1989-03-09T20:17:52.403Z
# 1         faith.lopez@example.com  1977-05-06T04:48:37.714Z
# 2      harper.ginnish@example.com  1951-08-26T01:29:01.739Z
# 3       carl.andersen@example.com  1981-09-06T11:51:40.080Z
# 4     teus.vijfvinkel@example.com  1993-08-01T04:16:14.118Z
# 5          jack.sirko@example.com  1975-05-10T11:36:18.943Z
# 6        darryl.bates@example.com  1957-06-01T08:41:53.497Z
# 7            ard.qsmy@example.com  1946-01-30T08:22:03.447Z
# 8        manuel.kelly@example.com  1956-11-19T09:41:11.246Z
# 9  lucasorluke.flores@example.com  1997-09-14T19:36:45.575Z
#
#                                             Picture
# 0    https://randomuser.me/api/portraits/men/53.jpg
# 1  https://randomuser.me/api/portraits/women/79.jpg
# 2  https://randomuser.me/api/portraits/women/39.jpg
# 3    https://randomuser.me/api/portraits/men/70.jpg
# 4    https://randomuser.me/api/portraits/men/80.jpg
# 5    https://randomuser.me/api/portraits/men/49.jpg
# 6    https://randomuser.me/api/portraits/men/90.jpg
# 7    https://randomuser.me/api/portraits/men/36.jpg
# 8    https://randomuser.me/api/portraits/men/53.jpg
# 9    https://randomuser.me/api/portraits/men/54.jpg
